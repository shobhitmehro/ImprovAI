# %%
import sqlite3 as sq
import pandas as pd
import numpy as np

# %%
con = sq.connect("data/wjazzd.db")
cursor = con.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")

# Fetch all results
tables = cursor.fetchall()

# Print the table names
print("Table names in the Weimar Jazz Database:")
for table in tables:
    print(table[0])
df = pd.read_sql_query("SELECT * FROM solo_info", con)

df.head(10)
# Out:
# Table names in the Weimar Jazz Database:
# melody
# sqlite_sequence
# beats
# sections
# melody_type
# transcription_info
# solo_info
# record_info
# track_info
# composition_info
# esac_info
# popsong_info
# db_info
#    melid  trackid  compid  recordid     performer                   title  \
# 0      1        1       1         1    Art Pepper            Anthropology
# 1      2        2       2         2    Art Pepper       Blues for Blanche
# 2      3        3       3         1    Art Pepper              Desafinado
# 3      4        4       4         1    Art Pepper        In a Mellow Tone
# 4      5        5       5         2    Art Pepper                Stardust
# 5      6        5       5         2    Art Pepper                Stardust
# 6      7        6       6         3  Benny Carter            I Got It Bad
# 7      8        7       7         4  Benny Carter  It's a Wonderful World
# 8      9        7       7         4  Benny Carter  It's a Wonderful World
# 9     10        8       8         4  Benny Carter            Just Friends
#
#   titleaddon  solopart instrument  style  avgtempo tempoclass rhythmfeel  \
# 0                    1         cl   COOL     218.8         UP      SWING
# 1                    1         as   COOL     198.9         UP      SWING
# 2                    1         as   COOL     140.5  MEDIUM UP      LATIN
# 3                    1         cl   COOL     167.6  MEDIUM UP      SWING
# 4                    1         as   COOL      60.7       SLOW     BALLAD
# 5                    2         as   COOL      60.2       SLOW     BALLAD
# 6                    1         as  SWING      68.2       SLOW      SWING
# 7                    1         as  SWING     124.2     MEDIUM      SWING
# 8                    2         as  SWING     127.2     MEDIUM      SWING
# 9                    1         as  SWING     204.9         UP      SWING
#
#       key signature                                      chord_changes  \
# 0  Bb-maj       4/4  A1: ||Bb6 G7 |C-7 F7 |Bb G-7 |C-7 F7 |F-7 Bb7 ...
# 1  Eb-maj       4/4  A1: ||Eb7   |Ab7   |Eb7   |Eb7   |Ab7   |Ab7  ...
# 2   F-maj       4/4  A1: ||Fj7   |Fj7   |G7alt   |G7alt   |G-7   |C...
# 3  Eb-maj       4/4  A1: ||F7   |Bb7   |Eb6   |Eb6   |Bb-7   |Eb7  ...
# 4  Eb-maj       4/4  A1: ||Ab6   |Ab6   |Ab-6   |Ab-6 Db7 |Eb F-7 |...
# 5  Eb-maj       4/4  B1: ||Ab6   |Ab6   |Ab-6   |Db7   |Ebj7   |G-7...
# 6  Db-maj       4/4  A1: ||Dbj7   |F-7 Bb7 |Eb7   |Eb7   |Eb-7   |F...
# 7   C-maj       4/4  A1: ||Cj7   |E-7 A7 |D-7 G7 |Cj7   ||\nA2: ||C...
# 8   C-maj       4/4  A1: ||Cj7   |E-7 A7 |D- G7 |Cj7 G7 ||\nA2: ||C...
# 9  Bb-maj       4/4  A1: ||Bbj7   |Bbj7   |Bb-7   |Eb7   |Fj7   |Fj...
#
#    chorus_count
# 0             4
# 1            11
# 2             2
# 3             4
# 4             2
# 5             1
# 6             1
# 7             3
# 8             2
# 9             3
